# %% [markdown]
# <a href="https://colab.research.google.com/github/leodan52/Inmersion_Datos_Alura/blob/main/Inmersion_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula 01: Importando el dataset del proyecto

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'quit']

# %% [markdown]
# ## Montamos nuestro Google Drive donde tenemos el archivo CSV con el dataset

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##Importamos pandas y creamos un pandas.dataset para trabajar con los datos

# %%
import pandas as pd

inmuebles = pd.read_csv('/content/drive/MyDrive/Inmersion_datos_alura/inmuebles_bogota.csv')
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %%
inmuebles.shape # Salida (número de datos, número de campos)
# Out:
# (9520, 8)

# %%
inmuebles.columns # Los nombres de los campos
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %% [markdown]
# ##Renombrando las columnas

# %% [markdown]
# Dado que las columnas actuales poseen caraćteres especiales como vocales con acentos y la letra "ñ", esto podría dar problemas con el código más adelante

# %%
#Creamos un diccionario con los reemplazos para las columnas a renombrar
columnas = {
    'Baños' : 'Banios',
    'Área' : 'Area'
}
# Renombramos las columnas
inmuebles = inmuebles.rename(columns = columnas)
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 586   Apartamento       Apartamento en venta en Santa Barbara             3
# 8143         Casa                   Casa en venta en Fontibón             4
# 3872  Apartamento       Apartamento en venta en Santa Barbara             2
# 5034  Apartamento                Apartamento en venta en Suba             3
# 6941         Casa      Casa en venta en Bellavista Occidental             9
# 1257  Apartamento       Apartamento en venta en Santa Barbara             1
# 2417  Apartamento       Apartamento en venta en Puente Aranda             3
# 8771  Apartamento             Apartamento en venta en Usaquén             3
# 6061  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 9014         Casa                    Casa en venta en Usaquén             3
#
#       Banios  Area                 Barrio  \
# 586        3    89          Santa Barbara
# 8143       4   167               Fontibón
# ...

# %% [markdown]
# ## Resumen del contenido de la tabla

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banios        9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %% [markdown]
# ## Recurso iloc

# %% [markdown]
# El recuros iloc ayuda a hacer un filtro usando el índice

# %%
inmuebles.iloc[300]
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banios                                        1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %%
inmuebles.iloc[300:305] # Haciendo slide
# Out:
#             Tipo                          Descripcion  Habitaciones  Banios  \
# 300  Apartamento      Apartamento en venta en Kennedy             2       1
# 301  Apartamento  Apartamento en venta en Chico Norte             2       2
# 302  Apartamento      Apartamento en venta en Kennedy             3       2
# 303  Apartamento      Apartamento en venta en Kennedy             3       2
# 304  Apartamento     Apartamento en venta en Cedritos             4       4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
inmuebles['Valor'][300]
# Out:
# '$ 116.100.000'

# %%
inmuebles[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banios  \
# 300  Apartamento      Apartamento en venta en Kennedy             2       1
# 301  Apartamento  Apartamento en venta en Chico Norte             2       2
# 302  Apartamento      Apartamento en venta en Kennedy             3       2
# 303  Apartamento      Apartamento en venta en Kennedy             3       2
# 304  Apartamento     Apartamento en venta en Cedritos             4       4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %% [markdown]
# ## Calculando la media del área de los inmuebles

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %% [markdown]
# Se analiza uno de los barrios más ricos de Bogotá

# %%
inmuebles.Barrio == 'Chico Reservado'
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
sum(inmuebles.Barrio == 'Chico Reservado') # Numero de inmuebles en el barrio 'Chico Reservado'
# Out:
# 225

# %%
inmuebles_chico = inmuebles.Barrio == 'Chico Reservado'
inmuebles_chico
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
chico_reservado = inmuebles[inmuebles_chico]
chico_reservado.sample(10)
# Out:
#                      Tipo                                      Descripcion  \
# 2187          Apartamento          Apartamento en venta en Chico Reservado
# 1193          Apartamento          Apartamento en venta en Chico Reservado
# 3281          Apartamento          Apartamento en venta en Chico Reservado
# 7759          Apartamento          Apartamento en venta en Chico Reservado
# 9299          Apartamento          Apartamento en venta en Chico Reservado
# 2195          Apartamento          Apartamento en venta en Chico Reservado
# 6367          Apartamento          Apartamento en venta en Chico Reservado
# 3152          Apartamento          Apartamento en venta en Chico Reservado
# 5065          Apartamento          Apartamento en venta en Chico Reservado
# 4912  Oficina/Consultorio  Oficina/Consultorio en venta en Chico Reservado
#
#       Habitaciones  Banios  Area           Barrio  \
# 2187             3       3   168  Chico Reservado
# ...

# %%
chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %% [markdown]
# ##¿Cuántos barrios diferentes tengo en el dataset?

# %%
print(f'Tenemos un total de {len(inmuebles.Barrio.value_counts())} barrios')

inmuebles.Barrio.value_counts()
# Out:
# Tenemos un total de 149 barrios
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
print(f'Tenemos un total de {len(inmuebles.UPZ.value_counts())} UPZ')

inmuebles.UPZ.value_counts()
# Out:
# Tenemos un total de 63 UPZ
# Usaquén                                  1681
# CHAPINERO: Pardo Rubio + Chapinero       1274
# USAQUÉN: Country Club + Santa Bárbara     771
# Bosa Central                              591
# Kennedy Central                           589
#                                          ...
# Localidad Usme resto                        2
# Las Cruces                                  2
# La Macarena                                 1
# Fontibón San Pablo                          1
# Zona Franca                                 1
# Name: UPZ, Length: 63, dtype: int64

# %% [markdown]
# ## Creando un gráfico

# %%
inmuebles_barrio = inmuebles.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %%
inmuebles_barrio.head(10).plot.bar() # Top 10
# Out:
# <Axes: >

# %% [markdown]
# ## Desafios del Aula 01

# %% [markdown]
# 1. Promedio de área de todos los barrios, y realizar un gráfico con el top 10
# 2. Consultar otros datos estadísticos: conteo, mediana, valores mínimos y máximos.

# %%
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 3365         Casa         Casa en venta en Zona Noroccidental             3
# 7100  Apartamento                Apartamento en venta en Bosa             3
# 4181  Apartamento         Apartamento en venta en Los Rosales             1
# 6792         Casa                 Casa en venta en Libertador             4
# 3876  Apartamento            Apartamento en venta en Cedritos             3
# 5847  Apartamento  Apartamento en venta en Zona Noroccidental             2
# 9156  Apartamento            Apartamento en venta en Cedritos             2
# 924   Apartamento             Apartamento en venta en Kennedy             3
# 8615  Apartamento            Apartamento en venta en Cedritos             2
# 973          Casa                    Casa en venta en Kennedy             8
#
#       Banios  Area              Barrio                                 UPZ  \
# ...

# %%
inmuebles[['Barrio', 'Area']]
# Out:
#                       Barrio  Area
# 0         Zona Noroccidental    70
# 1                   Castilla   170
# 2            Chico Reservado   144
# 3                    Usaquén   154
# 4                Bella Suiza   128
# ...                      ...   ...
# 9515                 Kennedy    70
# 9516  Parque Central Bavaria   100
# 9517                Restrepo   383
# 9518                Engativa   183
# 9519                 Tintala    52
#
# [9520 rows x 2 columns]

# %% [markdown]
# ### Método 1: Usando un ciclo for

# %%
import numpy as np

# Usando la libreria numpy, ordenamos alfabeticamente los diferentes barrios
# y los guardamos en una variable

barrios = np.sort(inmuebles.Barrio.unique())
barrios
# Out:
# array(['Alameda', 'Alhambra', 'Andes Norte', 'Antonio Nariño',
#        'Barrancas', 'Barrios Unidos', 'Bella Suiza',
#        'Bellavista Occidental', 'Bochica', 'Bogotá D.C', 'Bosa',
#        'Bosa Piamonte', 'Bosa Porvenir', 'Bosque De Pinos',
#        'Bosque Popular', 'Boyaca ', 'Buenos Aires', 'Candelaria La Nueva',
#        'Cantagallo', 'Capellania', 'Casablanca', 'Castilla', 'Cedritos',
#        'Cerros De Suba', 'Chapinero', 'Chapinero Alto',
#        'Chapinero Central', 'Chico Navarra', 'Chico Norte',
#        'Chico Norte Ii', 'Chico Reservado', 'Ciudad Berna',
#        'Ciudad Bolívar', 'Ciudad Salitre', 'Ciudadela Colsubsidio',
#        'Colina Campestre', 'Colinas De Suba', 'Costa Azul',
#        'Eduardo Santos', 'El Batán', 'El Castillo', 'El Chicó',
#        'El Contador', 'El Plan', 'El Progreso', 'El Refugio', 'El Retiro',
#        'El Salitre', 'El Tunal', 'El Virrey', 'Engativa', 'Estrada',
# ...

# %%
# Creamos un dataframe vacio
area_estadistica = pd.DataFrame()

# Y recorremos cada barrio
for barrio in barrios:
  query = inmuebles.Barrio == barrio
  sub_dt = inmuebles[query]

  # Calculamos algunas cantidades estadísticas
  calculos = sub_dt[['Area']].describe().T
  calculos.index = [barrio]

  # Y concatenamos con el dataframe vacio anterior
  area_estadistica = pd.concat([area_estadistica, calculos], axis = 0)

area_estadistica.index.name = 'Barrio'
area_estadistica
# Out:
#                     count        mean         std   min     25%    50%  \
# Barrio
# Alameda               1.0   97.000000         NaN  97.0   97.00   97.0
# Alhambra             17.0  190.411765   99.782300  50.0  112.00  164.0
# Andes Norte           7.0  124.857143   49.780949  42.0  105.00  108.0
# Antonio Nariño       48.0  163.062500  151.023798  32.0   58.75   72.0
# Barrancas            15.0   70.200000    7.022413  63.0   63.00   75.0
# ...                   ...         ...         ...   ...     ...    ...
# Villa Maria          13.0  207.153846   47.310757  51.0  222.00  222.0
# Villas De Granada    22.0   86.590909   51.346312  50.0   64.00   64.0
# Villemar             18.0   76.888889   48.502139  45.0   54.25   59.0
# Zona Franca           1.0   54.000000         NaN  54.0   54.00   54.0
# Zona Noroccidental  877.0  135.785633  223.813808  16.0   61.00   78.0
#
#                        75%     max
# Barrio
# Alameda              97.00    97.0
# ...

# %% [markdown]
# ### Método 2: Usando groupby

# %%
area_estadistica = inmuebles[['Barrio','Area']].groupby('Barrio').describe()
area_estadistica.columns = [dato for _,dato in area_estadistica.columns]

area_estadistica
# Out:
#                     count        mean         std   min     25%    50%  \
# Barrio
# Alameda               1.0   97.000000         NaN  97.0   97.00   97.0
# Alhambra             17.0  190.411765   99.782300  50.0  112.00  164.0
# Andes Norte           7.0  124.857143   49.780949  42.0  105.00  108.0
# Antonio Nariño       48.0  163.062500  151.023798  32.0   58.75   72.0
# Barrancas            15.0   70.200000    7.022413  63.0   63.00   75.0
# ...                   ...         ...         ...   ...     ...    ...
# Villa Maria          13.0  207.153846   47.310757  51.0  222.00  222.0
# Villas De Granada    22.0   86.590909   51.346312  50.0   64.00   64.0
# Villemar             18.0   76.888889   48.502139  45.0   54.25   59.0
# Zona Franca           1.0   54.000000         NaN  54.0   54.00   54.0
# Zona Noroccidental  877.0  135.785633  223.813808  16.0   61.00   78.0
#
#                        75%     max
# Barrio
# Alameda              97.00    97.0
# ...

# %% [markdown]
# ### Creando gráficos

# %%
columnas = {
    'count' : 'contador',
    'mean' : 'promedio',
    'std' : 'd_estandar',
    '25%' : 'qt1',
    '50%' : 'mediana',
    '75%' : 'qt3'
}

area_estadistica = area_estadistica.rename(columns = columnas)

area_estadistica
# Out:
#                     contador    promedio  d_estandar   min     qt1  mediana  \
# Barrio
# Alameda                  1.0   97.000000         NaN  97.0   97.00     97.0
# Alhambra                17.0  190.411765   99.782300  50.0  112.00    164.0
# Andes Norte              7.0  124.857143   49.780949  42.0  105.00    108.0
# Antonio Nariño          48.0  163.062500  151.023798  32.0   58.75     72.0
# Barrancas               15.0   70.200000    7.022413  63.0   63.00     75.0
# ...                      ...         ...         ...   ...     ...      ...
# Villa Maria             13.0  207.153846   47.310757  51.0  222.00    222.0
# Villas De Granada       22.0   86.590909   51.346312  50.0   64.00     64.0
# Villemar                18.0   76.888889   48.502139  45.0   54.25     59.0
# Zona Franca              1.0   54.000000         NaN  54.0   54.00     54.0
# Zona Noroccidental     877.0  135.785633  223.813808  16.0   61.00     78.0
#
#                        qt3     max
# Barrio
# ...

# %%
area_promedio = area_estadistica['promedio'].sort_values(ascending = False)

area_promedio.head(10).plot(kind = 'bar', title = 'Top 10 Promedio de Áreas', ylabel = 'Área (m^2)')
# Out:
# <Axes: title={'center': 'Top 10 Promedio de Áreas'}, xlabel='Barrio', ylabel='Área (m^2)'>

# %%
inmuebles[inmuebles.Barrio == 'Modelia'].Tipo.value_counts()
# Out:
# Casa           21
# Apartamento    19
# Name: Tipo, dtype: int64

# %%
area_estadistica.loc['Modelia']
# Out:
# contador          40.000000
# promedio        4316.750000
# d_estandar     26259.427757
# min               48.000000
# qt1               87.750000
# mediana          155.500000
# qt3              224.000000
# max           166243.000000
# Name: Modelia, dtype: float64

# %%
area_d = area_estadistica['d_estandar'].sort_values(ascending = False)

area_d.head(10).plot(kind = 'bar', title = 'Top 10 desviación estándar del total de áreas', ylabel = 'Área (m^2)')
# Out:
# <Axes: title={'center': 'Top 10 desviación estándar del total de áreas'}, xlabel='Barrio', ylabel='Área (m^2)'>

# %%
area_contador = area_estadistica['contador'].sort_values(ascending = False)

area_contador.head(10).plot(kind = 'bar', title = 'Top 10 barrios con más inmuebles en venta', ylabel = 'count')
# Out:
# <Axes: title={'center': 'Top 10 barrios con más inmuebles en venta'}, xlabel='Barrio', ylabel='count'>

# %%
area_min = area_estadistica['min'].sort_values(ascending = False)

area_min.head(10).plot(kind = 'bar', title = 'Top 10 valores mínimos por barrio', ylabel = 'Área (m^2)')
# Out:
# <Axes: title={'center': 'Top 10 valores mínimos por barrio'}, xlabel='Barrio', ylabel='Área (m^2)'>

# %%
area_max = area_estadistica['max'].sort_values(ascending = False)

area_max.head(10).plot(kind = 'bar', title = 'Top 10 valores máximos por barrio', ylabel = 'Área (m^2)')
# Out:
# <Axes: title={'center': 'Top 10 valores máximos por barrio'}, xlabel='Barrio', ylabel='Área (m^2)'>

# %%
area_mediana = area_estadistica['mediana'].sort_values(ascending = False)

area_mediana.head(10).plot(kind = 'bar', title = 'Top 10 mediana de áreas por barrio', ylabel = 'Área (m^2)')
# Out:
# <Axes: title={'center': 'Top 10 mediana de áreas por barrio'}, xlabel='Barrio', ylabel='Área (m^2)'>

# %% [markdown]
# ## Limpiando memoria

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_1',
#  '_10',
#  '_11',
#  '_12',
#  '_13',
#  '_14',
#  '_15',
#  '_16',
#  '_17',
#  '_18',
#  '_19',
#  '_20',
#  '_21',
#  '_22',
#  '_23',
#  '_24',
#  '_25',
#  '_26',
#  '_27',
#  '_28',
#  '_29',
#  '_3',
#  '_30',
#  '_31',
#  '_32',
#  '_33',
#  '_34',
#  '_35',
#  '_36',
#  '_4',
#  '_5',
#  '_6',
#  '_8',
#  '_9',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i34',
#  '_i35',
#  '_i36',
#  '_i37',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'area_contador',
#  'area_d',
# ...

# %%
del area_contador, area_d, area_estadistica, area_max, area_mediana, area_min, area_promedio, barrio,
del barrios, calculos, chico_reservado, columnas, inmuebles_barrio, inmuebles_chico, query

dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_1',
#  '_10',
#  '_11',
#  '_12',
#  '_13',
#  '_14',
#  '_15',
#  '_16',
#  '_17',
#  '_18',
#  '_19',
#  '_20',
#  '_21',
#  '_22',
#  '_23',
#  '_24',
#  '_25',
#  '_26',
#  '_27',
#  '_28',
#  '_29',
#  '_3',
#  '_30',
#  '_31',
#  '_32',
#  '_33',
#  '_34',
#  '_35',
#  '_36',
#  '_37',
#  '_4',
#  '_5',
#  '_6',
#  '_8',
#  '_9',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i34',
#  '_i35',
#  '_i36',
#  '_i37',
#  '_i38',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'drive',
#  'exit',
# ...

# %% [markdown]
# # Aula 02: Tratamiento de Datos y Primeras Gráficas

# %%
inmuebles.sample(10)
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 8302  Apartamento             Apartamento en venta en Suba             3
# 1351         Casa            Casa en venta en Puente Largo             4
# 7530         Casa           Casa en venta en Santa Barbara             4
# 2202  Apartamento        Apartamento en venta en Chapinero             1
# 6893  Apartamento             Apartamento en venta en Suba             3
# 6726         Casa             Casa en venta en Teusaquillo             6
# 4635  Apartamento  Apartamento en venta en Chico Reservado             2
# 4662  Apartamento   Apartamento en venta en Barrios Unidos             3
# 457   Apartamento             Apartamento en venta en Bosa             3
# 3330  Apartamento         Apartamento en venta en Santa Fe             1
#
#       Banios  Area           Barrio                                     UPZ  \
# 8302       4   140             Suba                                    Suba
# ...

# %% [markdown]
# ## Convertir columna str numerica a flotante

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banios        9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.Valor[0]
# Out:
# '$ 360.000.000'

# %%
type(inmuebles.Valor[0])
# Out:
# str

# %%
inmuebles.Valor[0] + inmuebles.Valor[1] # Concatenar str
# Out:
# '$ 360.000.000$ 670.000.000'

# %%
inmuebles.Valor[0].split()
# Out:
# ['$', '360.000.000']

# %%
valor_ = inmuebles.Valor.str.split(expand = True)
inmuebles['Moneda'] = valor_[0]
inmuebles['Precio'] = valor_[1]

inmuebles.sample(5)
# Out:
#              Tipo                       Descripcion  Habitaciones  Banios  \
# 4249         Casa    Casa en venta en San Cristobal             3       1
# 7465         Casa       Casa en venta en Tunjuelito            10       5
# 1737         Casa             Casa en venta en Suba             5       4
# 1341         Casa         Casa en venta en Fontibón             3       2
# 5685  Apartamento  Apartamento en venta en Cedritos             2       2
#
#       Area         Barrio         UPZ          Valor Moneda       Precio
# 4249    80  San Cristobal     Sosiego  $ 120.000.000      $  120.000.000
# 7465   390     Tunjuelito  Tunjuelito  $ 700.000.000      $  700.000.000
# 1737   220           Suba        Suba  $ 845.000.000      $  845.000.000
# 1341    62       Fontibón    Fontibón  $ 187.000.000      $  187.000.000
# 5685    79       Cedritos     Usaquén  $ 354.000.000      $  354.000.000

# %%
inmuebles['Precio'] = inmuebles['Precio'].str.replace('.', '', regex = True)

# %%
inmuebles[['Precio', 'Barrio']]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banios        9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
inmuebles['Precio_Millon'] = inmuebles['Precio'].astype('float')/1_000_000
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banios         9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 3019  Apartamento  Apartamento en venta en Zona Noroccidental             2
# 2727     Edificio         Edificio en venta en Barrios Unidos             8
# 5001  Apartamento         Apartamento en venta en Los Rosales             2
# 8651  Apartamento       Apartamento en venta en Santa Barbara             1
# 7639  Apartamento       Apartamento en venta en Santa Barbara             3
# 2882  Apartamento                Apartamento en venta en Bosa             3
# 3795  Apartamento  Apartamento en venta en Portales Del Norte             3
# 9462         Casa                    Casa en venta en Kennedy            10
# 2263         Casa                    Casa en venta en Usaquén             4
# 432   Apartamento           Apartamento en venta en Chapinero             1
#
#       Banios  Area              Barrio                                    UPZ  \
# ...

# %% [markdown]
# ## Función describe

# %%
inmuebles.describe()
# Out:
#        Habitaciones       Banios           Area  Precio_Millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %%
inmuebles.describe().round(2)
# Out:
#        Habitaciones   Banios       Area  Precio_Millon
# count       9520.00  9520.00    9520.00        9520.00
# mean           3.07     2.45     146.66         602.06
# std            2.05     1.26    1731.38         704.60
# min            1.00     0.00       2.00          60.00
# 25%            2.00     2.00      57.00         250.00
# 50%            3.00     2.00      80.00         409.18
# 75%            3.00     3.00     135.00         680.00
# max          110.00     9.00  166243.00       16000.00

# %% [markdown]
# Modificamos la visualización de los datos

# %%
pd.set_option('display.precision', 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

inmuebles.describe()
# Out:
#        Habitaciones  Banios      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %%
inmuebles.loc[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banios  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110       2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %%
inmuebles[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banios  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110       2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %%
inmuebles.loc[inmuebles.Area == 2]
# Out:
#              Tipo                            Descripcion  Habitaciones  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3
#
#       Banios  Area         Barrio      UPZ          Valor Moneda     Precio  \
# 8401       1     2  San Cristobal  Sosiego  $ 180.000.000      $  180000000
#
#       Precio_Millon
# 8401         180.00

# %% [markdown]
# ## Visualización de los datos

# %%
inmuebles['Precio_Millon'].plot.hist(bins = 100)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### Usando Matplotlib y Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize = (10,6))

grafica = sns.histplot(data = inmuebles, x = 'Precio_Millon', kde = True, hue = 'Tipo')
grafica.set_title('Distribución de Valores en los inmuebles en Bogotá')

plt.xlim((50,1000))
plt.savefig('/content/drive/MyDrive/Inmersion_datos_alura/img/valor_unmueble.png', format = 'png')
plt.show()

# %% [markdown]
# ## Desafio

# %% [markdown]
# 1. Estudiar mejor el histograma de valores, seleccionar 3 tipos de inmuebles (refinar el gráfico)
# 2. Precio del metro cuadrado por barrio, y encontrar un gráfico adecuado para esta nueva variable

# %% [markdown]
# ### Desafío 1

# %% [markdown]
# Vamos a trabajar con los 3 tipos de inmuebles que más se repitan en los datos

# %%
inmuebles.Tipo.value_counts()
# Out:
# Apartamento            7327
# Casa                   2043
# Oficina/Consultorio      60
# Local                    38
# Edificio                 22
# Bodega                   13
# Finca                    11
# Lote                      6
# Name: Tipo, dtype: int64

# %% [markdown]
# Los tipo de datos qué poseen una mayor frecuencia son

# %%
tipo_sel = ['Apartamento', 'Casa', 'Oficina/Consultorio']

# %% [markdown]
# Creamos el gráfico anterior únicamente usando estos tipos

# %%
plt.figure(figsize = (10,6))

inmuebles_simpl = inmuebles[inmuebles.Tipo.isin(tipo_sel)]

grafica = sns.histplot(data = inmuebles_simpl, x = 'Precio_Millon', kde = True, hue = 'Tipo')
grafica.set_title('Distribución de Valores en los inmuebles en Bogotá')

plt.xlim((50,2000))
#plt.savefig('/content/drive/MyDrive/Inmersion_datos_alura/img/valor_unmueble.png', format = 'png')
plt.show()

# %% [markdown]
# Ahora vamos a modificar las etiquetas y el titulo

# %%
plt.figure(figsize = (12,8))
sns.set_theme(font_scale = 1.5)

grafica = sns.histplot(data = inmuebles_simpl, x = 'Precio_Millon', kde = True, hue = 'Tipo')
grafica.set_title('Distribución de precios en los inmuebles en Bogotá')
grafica.set_xlabel('Precio (Millones COP)')
grafica.set_ylabel('Frecuencia')

plt.xlim((50,2000))
#plt.savefig('/content/drive/MyDrive/Inmersion_datos_alura/img/valor_unmueble.png', format = 'png')
plt.show()

# %% [markdown]
# Cambiamos la paleta de colores

# %%
plt.figure(figsize = (12,8)) # Creamos lienzo y ajustamos tamanio
sns.set_theme(font_scale = 1.5) # Ajustamos el tamanio de la fuente

grafica = sns.histplot(data = inmuebles_simpl, x = 'Precio_Millon',
                       kde = True,
                       hue = 'Tipo',
                       palette = 'dark',  # Cambiamos colores
                       multiple="stack"   # Evitamos que las barras sean transparentes
                       )

grafica.set_title('Distribución de precios en los inmuebles en Bogotá')
grafica.set_xlabel('Precio (Millones COP)')
grafica.set_ylabel('Frecuencia')

plt.xlim((50,2000))
plt.savefig('/content/drive/MyDrive/Inmersion_datos_alura/img/valor_inmueble_top3.png', format = 'png')
plt.show()

# %% [markdown]
# Hacemos un zoom in para mirar el tipo Casa

# %%
plt.figure(figsize = (12,8))
sns.set_theme(font_scale = 1.5)

grafica = sns.histplot(data = inmuebles_simpl, x = 'Precio_Millon', kde = True, hue = 'Tipo', palette = 'dark',  multiple="stack")
grafica.set_title('Distribución de precios en los inmuebles en Bogotá')
grafica.set_xlabel('Precio (Millones COP)')
grafica.set_ylabel('Frecuencia')

plt.xlim((50,2000))
plt.ylim((0,110))
plt.savefig('/content/drive/MyDrive/Inmersion_datos_alura/img/valor_inmueble_top3_zoomin_1.png', format = 'png')
plt.show()

# %% [markdown]
# Ahora otro Zoom In para mirar el tipo Oficina y departamento

# %%
plt.figure(figsize = (12,8))
sns.set_theme(font_scale = 1.5)

grafica = sns.histplot(data = inmuebles_simpl, x = 'Precio_Millon', kde = True, hue = 'Tipo', palette = 'dark',  multiple="stack")
grafica.set_title('Distribución de precios en los inmuebles en Bogotá')
grafica.set_xlabel('Precio (Millones COP)')
grafica.set_ylabel('Frecuencia')

plt.xlim((50,2000))
plt.ylim((0,7))
plt.savefig('/content/drive/MyDrive/Inmersion_datos_alura/img/valor_inmueble_top3_zoomin_2.png', format = 'png')
plt.show()

# %% [markdown]
# ### Desafío 2

# %% [markdown]
# Visulizamos los datos

# %%
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 8606  Apartamento             Apartamento en venta en Kennedy             3
# 2043  Apartamento        Apartamento en venta en San Patricio             3
# 7333  Apartamento           Apartamento en venta en Las Aguas             3
# 6396  Apartamento             Apartamento en venta en Usaquén             2
# 1078  Apartamento           Apartamento en venta en Chapinero             2
# 3698         Casa                    Casa en venta en Tintala             4
# 3988  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 3710  Apartamento                Apartamento en venta en Bosa             3
# 1553         Casa                   Casa en venta en Engativa             4
# 201   Apartamento            Apartamento en venta en Cedritos             2
#
#       Banios  Area              Barrio                                    UPZ  \
# ...

# %% [markdown]
# Creamos una columna nueva con el precio del metro cuadrado en cada caso.

# %%
inmuebles['Precio_por_m2'] = inmuebles.Precio_Millon / inmuebles.Area

inmuebles.sample(10)
# Out:
#                      Tipo                                        Descripcion  \
# 6392          Apartamento                    Apartamento en venta en Tintala
# 2601  Oficina/Consultorio  Oficina/Consultorio en venta en Zona Noroccide...
# 9196          Apartamento               Apartamento en venta en Gran Granada
# 5176          Apartamento             Apartamento en venta en Nueva Castilla
# 8587          Apartamento                    Apartamento en venta en Kennedy
# 4507                 Casa                    Casa en venta en Barrios Unidos
# 4405          Apartamento                Apartamento en venta en Teusaquillo
# 5478          Apartamento                   Apartamento en venta en La Salle
# 6974                 Casa                           Casa en venta en Kennedy
# 2780          Apartamento        Apartamento en venta en Nicolas De Federman
#
#       Habitaciones  Banios  Area               Barrio  \
# 6392             2       1    45              Tintala
# ...

# %% [markdown]
# Obtenemos algunos datos estadístico del precio por metro cuadrado $m^2$

# %%
datos_est = inmuebles.groupby(by = 'Barrio').describe()

datos_est.sample(10)
# Out:
#               Habitaciones                                        Banios       \
#                      count  mean   std  min  25%  50%  75%    max  count mean
# Barrio
# Palermo              15.00  4.33  4.70 1.00 2.00 3.00 5.00  20.00  15.00 2.73
# Alameda               1.00  3.00   NaN 3.00 3.00 3.00 3.00   3.00   1.00 2.00
# Las Nieves           37.00  2.46  3.28 1.00 1.00 1.00 2.00  15.00  37.00 1.86
# La Estancia           5.00  2.80  0.45 2.00 3.00 3.00 3.00   3.00   5.00 1.80
# Villa Maria          13.00  4.69  0.75 3.00 5.00 5.00 5.00   5.00  13.00 3.69
# La Uribe             11.00 12.91 32.21 3.00 3.00 3.00 3.00 110.00  11.00 2.45
# Bosa Piamonte         2.00  6.00  0.00 6.00 6.00 6.00 6.00   6.00   2.00 4.00
# Usme                 51.00  2.73  1.02 1.00 2.00 3.00 3.00   7.00  51.00 1.69
# Suba                443.00  3.38  1.66 1.00 3.00 3.00 4.00  16.00 443.00 2.71
# Verbenal              6.00  2.00  0.00 2.00 2.00 2.00 2.00   2.00   6.00 1.33
#
# ...

# %%
datos_est.Precio_por_m2.sample(10)
# Out:
#                count  mean  std  min  25%  50%  75%  max
# Barrio
# Ingles          2.00  2.50 0.00 2.50 2.50 2.50 2.50 2.50
# Madelena       28.00  3.04 1.04 1.39 2.25 3.10 4.00 4.50
# Gran America   12.00  6.48 1.45 3.24 6.17 7.14 7.29 8.38
# Ricaurte        5.00  3.92 1.59 2.69 2.78 2.81 5.65 5.65
# La Soledad      8.00  3.60 0.89 2.07 3.10 3.69 4.19 4.76
# Santa Librada   2.00  1.95 0.91 1.31 1.63 1.95 2.27 2.59
# Florencia       1.00  3.79  NaN 3.79 3.79 3.79 3.79 3.79
# Las Ferias      2.00  1.72 0.00 1.72 1.72 1.72 1.72 1.72
# Lago De Suba    1.00  4.37  NaN 4.37 4.37 4.37 4.37 4.37
# Quirigua        8.00  2.78 0.43 2.15 2.61 2.78 3.19 3.20

# %% [markdown]
# Tomaremos el top 10 de promedios, con su respectiva desviación estándar

# %%
top_promedio_porM2 = datos_est.Precio_por_m2[['mean', 'std']].sort_values(by = 'mean', ascending=False).head(10)
top_promedio_porM2 = top_promedio_porM2.reset_index()
top_promedio_porM2
# Out:
#             Barrio  mean  std
# 0        El Virrey 10.20 2.01
# 1        Santa Ana  9.36 2.12
# 2        La Merced  8.98 1.01
# 3      Chico Norte  8.54 2.70
# 4      Los Rosales  8.17 2.75
# 5       El Refugio  7.96 2.74
# 6       Las Nieves  7.89 2.66
# 7        El Retiro  7.72 2.27
# 8  Chico Reservado  7.61 2.89
# 9        Chapinero  7.43 2.55

# %% [markdown]
# Vamos a probar varias graficas para encontrar la mejor

# %% [markdown]
# LinePlot

# %%
sns.set_theme()
plt.figure(figsize = (10,8))

sns.lineplot(data = top_promedio_porM2, y = 'mean', x = 'Barrio', marker = 'o')

sigma = top_promedio_porM2['std']
x = top_promedio_porM2['Barrio']
y = top_promedio_porM2['mean']
plt.errorbar(x = x, y = y, yerr=(sigma, sigma), fmt='none', color='r', capsize=5)

plt.title('Promedio del costo por m2 por barrio')
plt.xlabel('Barrio')
plt.ylabel('Promedio')
plt.xticks(rotation = 80)
plt.show()

# %% [markdown]
# Barplot

# %%
# Reiniciamos settings
sns.set_theme()
plt.figure(figsize = (10,8))

sns.barplot(data = top_promedio_porM2, y = 'mean', x = 'Barrio')

#Obtenemos la desviación estandar
sigma = top_promedio_porM2['std']

x = top_promedio_porM2['Barrio']
y = top_promedio_porM2['mean']

# Graficamos las barras de error
plt.errorbar(x = x, y = y, yerr=(sigma, sigma), fmt='none', color='k', capsize=5)

plt.title('Top 10 Promedio del costo por m2 por barrio')
plt.xlabel('Barrio')
plt.ylabel('Promedio (millones COP)')

# Rotamos las etiquetas de x para que los nombres no se solapen
plt.xticks(rotation = 80)

plt.savefig('/content/drive/MyDrive/Inmersion_datos_alura/img/top10_primedio_costo_m2.png', format = 'png')
plt.show()

# %% [markdown]
# ## Limpiando memoria

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_1',
#  '_10',
#  '_11',
#  '_12',
#  '_13',
#  '_14',
#  '_15',
#  '_16',
#  '_17',
#  '_18',
#  '_19',
#  '_20',
#  '_21',
#  '_22',
#  '_23',
#  '_24',
#  '_25',
#  '_26',
#  '_27',
#  '_28',
#  '_29',
#  '_3',
#  '_30',
#  '_31',
#  '_32',
#  '_33',
#  '_34',
#  '_35',
#  '_36',
#  '_37',
#  '_38',
#  '_39',
#  '_4',
#  '_41',
#  '_42',
#  '_43',
#  '_44',
#  '_45',
#  '_47',
#  '_5',
#  '_50',
#  '_51',
#  '_52',
#  '_53',
#  '_54',
#  '_55',
#  '_56',
#  '_57',
#  '_59',
#  '_6',
#  '_66',
#  '_67',
#  '_68',
#  '_69',
#  '_70',
#  '_8',
#  '_9',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
# ...

# %%
del datos_est, grafica, inmuebles_simpl, sigma, tipo_sel, top_promedio_porM2, valor_

dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_1',
#  '_10',
#  '_11',
#  '_12',
#  '_13',
#  '_14',
#  '_15',
#  '_16',
#  '_17',
#  '_18',
#  '_19',
#  '_20',
#  '_21',
#  '_22',
#  '_23',
#  '_24',
#  '_25',
#  '_26',
#  '_27',
#  '_28',
#  '_29',
#  '_3',
#  '_30',
#  '_31',
#  '_32',
#  '_33',
#  '_34',
#  '_35',
#  '_36',
#  '_37',
#  '_38',
#  '_39',
#  '_4',
#  '_41',
#  '_42',
#  '_43',
#  '_44',
#  '_45',
#  '_47',
#  '_5',
#  '_50',
#  '_51',
#  '_52',
#  '_53',
#  '_54',
#  '_55',
#  '_56',
#  '_57',
#  '_59',
#  '_6',
#  '_66',
#  '_67',
#  '_68',
#  '_69',
#  '_70',
#  '_73',
#  '_8',
#  '_9',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
# ...

# %% [markdown]
# # Aula 03: Profundizando el análisis exploratorio e insights

# %% [markdown]
# ## Solución Desafio 2 por los profes

# %% [markdown]
# #### Obtenemos la sumatoria de las variables del data set

# %%
barrios_sumatoria = inmuebles.groupby('Barrio').sum()
barrios_sumatoria
# Out:
# <ipython-input-75-ecfbc27f21fe>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   barrios_sumatoria = inmuebles.groupby('Barrio').sum()
#                     Habitaciones  Banios    Area  Precio_Millon  Precio_por_m2
# Barrio
# Alameda                        3       2      97         580.00           5.98
# Alhambra                      51      50    3237       12790.00          73.56
# Andes Norte                   21      20     874        4967.00          42.35
# Antonio Nariño               207     120    7827       22042.65         169.47
# Barrancas                     43      32    1053        4712.00          66.24
# ...                          ...     ...     ...            ...            ...
# Villa Maria                   61      48    2693        5237.00          26.58
# ...

# %% [markdown]
# #### Se obtiene el valor por $m^2$ por Barrio

# %%
promedio_acumulativo = (barrios_sumatoria['Precio_Millon'] / barrios_sumatoria['Area']).to_frame()
promedio_acumulativo
# Out:
#                       0
# Barrio
# Alameda            5.98
# Alhambra           3.95
# Andes Norte        5.68
# Antonio Nariño     2.82
# Barrancas          4.47
# ...                 ...
# Villa Maria        1.94
# Villas De Granada  3.26
# Villemar           3.95
# Zona Franca        2.96
# Zona Noroccidental 4.57
#
# [149 rows x 1 columns]

# %%
m2_barrio = dict(promedio_acumulativo[0])
m2_barrio
# Out:
# {'Alameda': 5.979381443298969,
#  'Alhambra': 3.95118937287612,
#  'Andes Norte': 5.683066361556064,
#  'Antonio Nariño': 2.816232272901495,
#  'Barrancas': 4.4748338081671415,
#  'Barrios Unidos': 2.9599171141243064,
#  'Bella Suiza': 6.2905507012394,
#  'Bellavista Occidental': 2.522711390635919,
#  'Bochica': 3.4078212290502794,
#  'Bogotá D.C': 5.212760277629472,
#  'Bosa': 2.6778451358697213,
#  'Bosa Piamonte': 1.175,
#  'Bosa Porvenir': 3.1666666666666665,
#  'Bosque De Pinos': 6.046475195822455,
#  'Bosque Popular': 3.864097363083164,
#  'Boyaca ': 2.637421499815294,
#  'Buenos Aires': 2.6,
#  'Candelaria La Nueva': 4.0625,
#  'Cantagallo': 5.71920581655481,
#  'Capellania': 4.316791690709752,
#  'Casablanca': 6.245421245421245,
#  'Castilla': 3.4035893155258763,
#  'Cedritos': 5.027419586695463,
#  'Cerros De Suba': 6.202830188679245,
#  'Chapinero': 4.58018576602501,
#  'Chapinero Alto': 6.4239336492891,
#  'Chapinero Central': 6.360286919831224,
# ...

# %%
inmuebles.sample(5)
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 6605         Casa                Casa en venta en Engativa             3
# 5061         Lote                 Lote en venta en Usaquén             4
# 3272  Apartamento          Apartamento en venta en Usaquén             2
# 6295  Apartamento  Apartamento en venta en Chico Reservado             3
# 2462         Casa            Casa en venta en Los Mártires             5
#
#       Banios  Area           Barrio                                 UPZ  \
# 6605       1   125         Engativa                            Engativá
# 5061       2   218          Usaquén                             Usaquén
# 3272       2    77          Usaquén                             Usaquén
# 6295       4   130  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 2462       6   320     Los Mártires                           La Sabana
#
#                 Valor Moneda      Precio  Precio_Millon  Precio_por_m2
# ...

# %%
inmuebles['Valor_m2_barrio'] = inmuebles['Barrio']
inmuebles['Valor_m2_barrio'] = inmuebles['Valor_m2_barrio'].map(m2_barrio)

inmuebles.sample(5)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 7603         Casa                    Casa en venta en Usaquén             4
# 1034  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 5986  Apartamento     Apartamento en venta en Chico Reservado             3
# 3857  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 8813  Apartamento            Apartamento en venta en Fontibón             3
#
#       Banios  Area              Barrio                                 UPZ  \
# 7603       5   240             Usaquén                             Usaquén
# 1034       2    87  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 5986       2    89     Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 3857       2    60  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 8813       2    52            Fontibón                            Fontibón
#
# ...

# %% [markdown]
# ¿Qué diferencia hay entre el primer método y el segundo para el cálculo del promedio?

# %%
abs(inmuebles['Precio_por_m2'] - inmuebles['Valor_m2_barrio'])
# Out:
# 0      0.57
# 1      0.54
# 2      0.33
# 3      0.12
# 4      1.29
#        ...
# 9515   0.76
# 9516   0.59
# 9517   0.57
# 9518   1.06
# 9519   1.01
# Length: 9520, dtype: float64

# %% [markdown]
# #### Gráfica

# %% [markdown]
# Se obtiene el top 10 de los barrios con más inmuebles en venta

# %%
top_barrios = inmuebles['Barrio'].value_counts()[:10].index
top_barrios
# Out:
# Index(['Usaquén', 'Zona Noroccidental', 'Bosa', 'Kennedy', 'Cedritos',
#        'Barrios Unidos', 'Engativa', 'Suba', 'Santa Barbara', 'Chapinero'],
#       dtype='object')

# %%
promedio_acumulativo.rename(columns = {0 : 'Valor_m2_barrio'}, inplace = True)
promedio_acumulativo.reset_index(inplace = True)
promedio_acumulativo
# Out:
#                  Barrio  Valor_m2_barrio
# 0               Alameda             5.98
# 1              Alhambra             3.95
# 2           Andes Norte             5.68
# 3        Antonio Nariño             2.82
# 4             Barrancas             4.47
# ..                  ...              ...
# 144         Villa Maria             1.94
# 145   Villas De Granada             3.26
# 146            Villemar             3.95
# 147         Zona Franca             2.96
# 148  Zona Noroccidental             4.57
#
# [149 rows x 2 columns]

# %% [markdown]
# Filtramos los valores por $m^2$ del top 10 calculado anteriormente

# %%
promedio_acumulativo.query('Barrio in @top_barrios')
# Out:
#                  Barrio  Valor_m2_barrio
# 5        Barrios Unidos             2.96
# 10                 Bosa             2.68
# 22             Cedritos             5.03
# 24            Chapinero             4.58
# 50             Engativa             2.89
# 63              Kennedy             3.38
# 125       Santa Barbara             5.85
# 132                Suba             4.32
# 138             Usaquén             5.66
# 148  Zona Noroccidental             4.57

# %% [markdown]
# Creamos una gráfica para visualizar el costo por $m^2$ del top 10

# %%
sns.set_theme()
plt.figure(figsize = (10, 8))

ax = sns.barplot(x = 'Barrio', y = 'Valor_m2_barrio', data = promedio_acumulativo.query('Barrio in @top_barrios'))
ax.tick_params(axis = 'x', rotation = 45)

plt.show()

# %% [markdown]
# Ahora graficamos el costo por $m^2$ por inmueble y por barrio del top 10 anterior

# %%
sns.set_theme()
plt.figure(figsize = (10, 8))

ax = sns.boxplot(x = 'Barrio', y = 'Precio_por_m2', data = inmuebles.query('Barrio in @top_barrios'))
ax.tick_params(axis = 'x', rotation = 45)

plt.show()

# %% [markdown]
# Omitimos los inmuebles con valores por $m^2$ mayores a 15 millones de COP

# %%
sns.set_theme()
plt.figure(figsize = (10, 8))

ax = sns.boxplot(x = 'Barrio', y = 'Precio_por_m2', data = inmuebles.query('Barrio in @top_barrios & Precio_por_m2 < 15'))
ax.tick_params(axis = 'x', rotation = 45)

plt.show()

# %% [markdown]
# Gráficamos el área de los inmuebles del top por debajo de los $500m^2$

# %%
sns.set_theme()
plt.figure(figsize = (10, 8))

ax = sns.boxplot(x = 'Barrio', y = 'Area', data = inmuebles.query('Barrio in @top_barrios & Area < 500'))
ax.tick_params(axis = 'x', rotation = 45)

plt.show()

# %%
inmuebles.query('Barrio in @top_barrios & Area < 500').groupby('Barrio').describe()['Area']
# Out:
#                      count   mean   std   min   25%    50%    75%    max
# Barrio
# Barrios Unidos      459.00 117.36 86.73 28.00 61.00  84.00 133.50 440.00
# Bosa                587.00  56.63 36.12 31.00 47.00  47.00  53.00 344.00
# Cedritos            553.00  96.19 44.18 27.00 69.00  87.00 108.00 387.00
# Chapinero           318.00 130.50 86.63 15.00 67.25 104.00 165.75 480.00
# Engativa            455.00 104.42 81.87 21.00 54.00  70.00 110.50 481.00
# Kennedy             588.00 102.90 94.35 28.00 49.00  59.50  98.00 480.00
# Santa Barbara       433.00 118.39 77.50 30.00 66.00  88.00 152.00 496.00
# Suba                430.00 121.47 93.14 34.00 62.00  85.00 135.00 494.00
# Usaquén            1096.00 123.27 80.45 24.00 69.00  93.00 152.00 498.00
# Zona Noroccidental  850.00 113.56 94.10 16.00 60.00  78.00 109.00 495.00

# %% [markdown]
# Visualizamos ahora el precio bruto de los inmuebles del top 10 por debajo de los 2000 millones

# %%
sns.set_theme()
plt.figure(figsize = (10, 8))

ax = sns.boxplot(x = 'Barrio', y = 'Precio_Millon', data = inmuebles.query('Barrio in @top_barrios & Precio_Millon < 2000'))
ax.tick_params(axis = 'x', rotation = 45)

plt.show()

# %% [markdown]
# ## Importando datos del DANE

# %% [markdown]
# Vamos a traer datos estadísticos de la ciudad de Bogotá, directamente del DANE y vamos a ver como estos datos nos ayudarían en inclusión de nuevas variables para el cálculo del precio de los inmuebles en la ciudad de Bogotá.
#
# Encuesta Multiproposito de Bogotá para obtener información socio-económica y de entorno urbano de los habitantes de Bogotá para la formulación, seguimiento y evaluación de las políticas distritales.
#
# https://microdatos.dane.gov.co/index.php/catalog/743

# %%
datos_raw = pd.read_csv('/content/drive/MyDrive/Inmersion_datos_alura/datos_varios_colombia/Identificación (Capítulo A).csv', sep = ';', encoding = 'latin-1')
datos_raw.head()
# Out:
#    DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0  3004346.00    11  11001      1           3.00         Santa Fe
# 1  3004347.00    11  11001      1          14.00     Los Mártires
# 2  3004348.00    11  11001      1           3.00         Santa Fe
# 3  3004349.00    11  11001      1           1.00          Usaquén
# 4  3004350.00    11  11001      1           1.00          Usaquén
#
#    COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# 0         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 1          37.00                            Santa Isabel     11001162
# 2         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 3         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
# 4         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
#
#                            NOMBRE_ESTRATO             FEX_C
# 0  SANTA FE: Las Nieves + Sagrado Corazón  13,2266692027239
# ...

# %%
datos_raw.shape
# Out:
# (106467, 11)

# %% [markdown]
# Vamos a filtrar para quedarnos con los datos referentes al distrito de Bogotá (11001)

# %%
datos_raw = datos_raw.loc[datos_raw.MPIO == 11001]
datos_raw.shape
# Out:
# (86504, 11)

# %% [markdown]
# Importamos las bases de datos que usaremos en el modelo predictivo

# %%
datos_b = pd.read_csv('/content/drive/MyDrive/Inmersion_datos_alura/datos_varios_colombia/Datos de la vivenda y su entorno (Capítulo B).csv', sep = ';', encoding = 'latin-1')
datos_c = pd.read_csv('/content/drive/MyDrive/Inmersion_datos_alura/datos_varios_colombia/Condiciones habitacionales del hogar (Capítulo C).csv', sep = ';', encoding = 'latin-1')
datos_e = pd.read_csv('/content/drive/MyDrive/Inmersion_datos_alura/datos_varios_colombia/Composición del hogar y demografía (Capítulo E).csv', sep = ';', encoding = 'latin-1')
datos_h = pd.read_csv('/content/drive/MyDrive/Inmersion_datos_alura/datos_varios_colombia/Educaci¢n (Capitulo H).csv', sep = ';', encoding = 'latin-1')
datos_l = pd.read_csv('/content/drive/MyDrive/Inmersion_datos_alura/datos_varios_colombia/Percepción sobre las condiciones de vida y el desempeño institucional (Capítulo L).csv', sep = ';', encoding = 'latin-1')
datos_k = pd.read_csv('/content/drive/MyDrive/Inmersion_datos_alura/datos_varios_colombia/Fuerza de trabajo (Capítulo K).csv', sep = ';', encoding = 'latin-1')
# Out:
# <ipython-input-93-35e9a66c8ddc>:2: DtypeWarning: Columns (4,25,30,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_c = pd.read_csv('/content/drive/MyDrive/Inmersion_datos_alura/datos_varios_colombia/Condiciones habitacionales del hogar (Capítulo C).csv', sep = ';', encoding = 'latin-1')
# <ipython-input-93-35e9a66c8ddc>:3: DtypeWarning: Columns (66) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_e = pd.read_csv('/content/drive/MyDrive/Inmersion_datos_alura/datos_varios_colombia/Composición del hogar y demografía (Capítulo E).csv', sep = ';', encoding = 'latin-1')
# <ipython-input-93-35e9a66c8ddc>:4: DtypeWarning: Columns (26,81) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_h = pd.read_csv('/content/drive/MyDrive/Inmersion_datos_alura/datos_varios_colombia/Educaci¢n (Capitulo H).csv', sep = ';', encoding = 'latin-1')
# ...

# %% [markdown]
# Hacemos un left join con esas bases de datos usando de pivote el DIRECTORIO

# %%
datos_dane = pd.merge(datos_raw, datos_b, on = 'DIRECTORIO', how = 'left' )
datos_dane.shape
# Out:
# (86504, 73)

# %%
datos_dane = pd.merge(datos_dane, datos_c, on = 'DIRECTORIO', how = 'left' )
datos_dane.shape
# Out:
# (87061, 214)

# %%
datos_dane = pd.merge(datos_dane, datos_e, on = 'DIRECTORIO', how = 'left' )
datos_dane.shape
# Out:
# <ipython-input-96-a297d47bd738>:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'FEX_C_x'} in the result is deprecated and will raise a MergeError in a future version.
#   datos_dane = pd.merge(datos_dane, datos_e, on = 'DIRECTORIO', how = 'left' )
# (238559, 281)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238559 entries, 0 to 238558
# Columns: 281 entries, DIRECTORIO to FEX_C_y
# dtypes: float64(140), int64(126), object(15)
# memory usage: 513.3+ MB

# %% [markdown]
# Continuará...

# %% [markdown]
# ## Desafios del Aula 03

# %% [markdown]
# 1. Dar un vistazo a la base de datos del DANE, entender estas variables, conceptualmente para entender mejor el contexto de esta base.
# 2. Organizar tu notebook para tu proyecto quede mejor presentado

# %% [markdown]
# ## Limpiando memoria

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_1',
#  '_10',
#  '_11',
#  '_12',
#  '_13',
#  '_14',
#  '_15',
#  '_16',
#  '_17',
#  '_18',
#  '_19',
#  '_20',
#  '_21',
#  '_22',
#  '_23',
#  '_24',
#  '_25',
#  '_26',
#  '_27',
#  '_28',
#  '_29',
#  '_3',
#  '_30',
#  '_31',
#  '_32',
#  '_33',
#  '_34',
#  '_35',
#  '_36',
#  '_37',
#  '_38',
#  '_39',
#  '_4',
#  '_41',
#  '_42',
#  '_43',
#  '_44',
#  '_45',
#  '_47',
#  '_5',
#  '_50',
#  '_51',
#  '_52',
#  '_53',
#  '_54',
#  '_55',
#  '_56',
#  '_57',
#  '_59',
#  '_6',
#  '_66',
#  '_67',
#  '_68',
#  '_69',
#  '_70',
#  '_73',
#  '_74',
#  '_75',
#  '_76',
#  '_77',
#  '_78',
#  '_79',
#  '_8',
#  '_80',
#  '_81',
#  '_82',
#  '_83',
#  '_88',
#  '_9',
#  '_90',
#  '_91',
#  '_92',
#  '_94',
#  '_95',
#  '_96',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
# ...

# %%
del barrios_sumatoria, m2_barrio, promedio_acumulativo, top_barrios, x, y

dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_1',
#  '_10',
#  '_11',
#  '_12',
#  '_13',
#  '_14',
#  '_15',
#  '_16',
#  '_17',
#  '_18',
#  '_19',
#  '_20',
#  '_21',
#  '_22',
#  '_23',
#  '_24',
#  '_25',
#  '_26',
#  '_27',
#  '_28',
#  '_29',
#  '_3',
#  '_30',
#  '_31',
#  '_32',
#  '_33',
#  '_34',
#  '_35',
#  '_36',
#  '_37',
#  '_38',
#  '_39',
#  '_4',
#  '_41',
#  '_42',
#  '_43',
#  '_44',
#  '_45',
#  '_47',
#  '_5',
#  '_50',
#  '_51',
#  '_52',
#  '_53',
#  '_54',
#  '_55',
#  '_56',
#  '_57',
#  '_59',
#  '_6',
#  '_66',
#  '_67',
#  '_68',
#  '_69',
#  '_70',
#  '_73',
#  '_74',
#  '_75',
#  '_76',
#  '_77',
#  '_78',
#  '_79',
#  '_8',
#  '_80',
#  '_81',
#  '_82',
#  '_83',
#  '_88',
#  '_9',
#  '_90',
#  '_91',
#  '_92',
#  '_94',
#  '_95',
#  '_96',
#  '_98',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
# ...
