# %% [markdown]
# <a href="https://colab.research.google.com/github/leodan52/Inmersion_Datos_Alura/blob/main/Inmersion_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula 01: Importando el dataset del proyecto

# %% [markdown]
# ##Montamos nuestro Google Drive donde tenemos el archivo CSV con el dataset

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Importamos pandas y creamos un pandas.dataset para trabajar con los datos

# %%
import pandas as pd

inmuebles = pd.read_csv('/content/drive/MyDrive/Inmersion_datos_alura/inmuebles_bogota.csv')
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# 3    $ 890.000.000
# 4    $ 970.000.000

# %%
inmuebles.shape # Salida (número de datos, número de campos)
# Out:
# (9520, 8)

# %%
inmuebles.columns # Los nombres de los campos
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %% [markdown]
# ##Renombrando las columnas

# %% [markdown]
# Dado que las columnas actuales poseen caraćteres especiales como vocales con acentos y la letra "ñ", esto podría dar problemas con el código más adelante

# %%
#Creamos un diccionario con los reemplazos para las columnas a renombrar
columnas = {
    'Baños' : 'Banios',
    'Área' : 'Area'
}
# Renombramos las columnas
inmuebles = inmuebles.rename(columns = columnas)
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 8962  Apartamento     Apartamento en venta en Chico Reservado             3
# 6227         Casa                   Casa en venta en Engativa             4
# 2768  Apartamento            Apartamento en venta en Cedritos             3
# 3261         Casa         Casa en venta en Zona Noroccidental             4
# 623   Apartamento  Apartamento en venta en Zona Noroccidental             3
# 3207  Apartamento             Apartamento en venta en Usaquén             3
# 8176         Casa                    Casa en venta en Kennedy             5
# 6148  Apartamento             Apartamento en venta en Tintala             1
# 5506  Apartamento            Apartamento en venta en Engativa             3
# 8092         Casa                   Casa en venta en Cedritos             4
#
#       Banios  Area              Barrio                                 UPZ  \
# 8962       4   128     Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 6227       2   481            Engativa                            Engativá
# 2768       3   127            Cedritos                             Usaquén
# 3261       5   187  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 623        2    56  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 3207       2    88             Usaquén                             Usaquén
# 8176       4   320             Kennedy                     Kennedy Central
# 6148       1    32             Tintala                             Tintala
# 5506       2    70            Engativa                            Engativá
# 8092       5   516            Cedritos                             Usaquén
#
#                 Valor
# 8962    $ 780.000.000
# 6227  $ 1.158.199.973
# 2768    $ 690.000.000
# 3261  $ 1.050.000.000
# 623     $ 248.000.000
# 3207    $ 408.000.000
# 8176    $ 680.000.000
# 6148    $ 115.000.000
# 5506    $ 298.500.000
# 8092  $ 2.350.000.000

# %% [markdown]
# ## Resumen del contenido de la tabla

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banios        9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %% [markdown]
# ## Recurso iloc

# %% [markdown]
# El recuros iloc ayuda a hacer un filtro usando el índice

# %%
inmuebles.iloc[300]
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banios                                        1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %%
inmuebles.iloc[300:305] # Haciendo slide
# Out:
#             Tipo                          Descripcion  Habitaciones  Banios  \
# 300  Apartamento      Apartamento en venta en Kennedy             2       1
# 301  Apartamento  Apartamento en venta en Chico Norte             2       2
# 302  Apartamento      Apartamento en venta en Kennedy             3       2
# 303  Apartamento      Apartamento en venta en Kennedy             3       2
# 304  Apartamento     Apartamento en venta en Cedritos             4       4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
inmuebles['Valor'][300]
# Out:
# '$ 116.100.000'

# %%
inmuebles[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banios  \
# 300  Apartamento      Apartamento en venta en Kennedy             2       1
# 301  Apartamento  Apartamento en venta en Chico Norte             2       2
# 302  Apartamento      Apartamento en venta en Kennedy             3       2
# 303  Apartamento      Apartamento en venta en Kennedy             3       2
# 304  Apartamento     Apartamento en venta en Cedritos             4       4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %% [markdown]
# ##Calculando la media del área de los inmuebles

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %% [markdown]
# Se analiza uno de los barrios más ricos de Bogotá

# %%
inmuebles.Barrio == 'Chico Reservado'
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
sum(inmuebles.Barrio == 'Chico Reservado') # Numero de inmuebles en el barrio 'Chico Reservado'
# Out:
# 225

# %%
inmuebles_chico = inmuebles.Barrio == 'Chico Reservado'
inmuebles_chico
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
chico_reservado = inmuebles[inmuebles_chico]
chico_reservado.sample(10)
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 5573  Apartamento  Apartamento en venta en Chico Reservado             2
# 1943  Apartamento  Apartamento en venta en Chico Reservado             2
# 5081  Apartamento  Apartamento en venta en Chico Reservado             3
# 4004  Apartamento  Apartamento en venta en Chico Reservado             2
# 5651  Apartamento  Apartamento en venta en Chico Reservado             3
# 3392         Casa         Casa en venta en Chico Reservado             4
# 4683  Apartamento  Apartamento en venta en Chico Reservado             3
# 1193  Apartamento  Apartamento en venta en Chico Reservado             4
# 2580  Apartamento  Apartamento en venta en Chico Reservado             3
# 3593  Apartamento  Apartamento en venta en Chico Reservado             2
#
#       Banios  Area           Barrio                                 UPZ  \
# 5573       2    88  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 1943       3   138  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 5081       3   140  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 4004       1    78  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 5651       4   333  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 3392       4   285  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 4683       4   164  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 1193       4   175  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 2580       4   184  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 3593       2   103  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#                 Valor
# 5573    $ 640.000.000
# 1943    $ 579.000.000
# 5081    $ 880.000.000
# 4004    $ 630.000.000
# 5651  $ 5.500.000.000
# 3392    $ 870.000.000
# 4683  $ 1.200.000.000
# 1193    $ 850.000.000
# 2580  $ 1.200.000.000
# 3593    $ 450.000.000

# %%
chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %% [markdown]
# ##¿Cuántos barrios diferentes tengo en el dataset?

# %%
print(f'Tenemos un total de {len(inmuebles.Barrio.value_counts())} barrios')

inmuebles.Barrio.value_counts()
# Out:
# Tenemos un total de 149 barrios
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
print(f'Tenemos un total de {len(inmuebles.UPZ.value_counts())} UPZ')

inmuebles.UPZ.value_counts()
# Out:
# Tenemos un total de 63 UPZ
# Usaquén                                  1681
# CHAPINERO: Pardo Rubio + Chapinero       1274
# USAQUÉN: Country Club + Santa Bárbara     771
# Bosa Central                              591
# Kennedy Central                           589
#                                          ...
# Localidad Usme resto                        2
# Las Cruces                                  2
# La Macarena                                 1
# Fontibón San Pablo                          1
# Zona Franca                                 1
# Name: UPZ, Length: 63, dtype: int64

# %% [markdown]
# ##Creando un gráfico

# %%
inmuebles_barrio = inmuebles.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %%
inmuebles_barrio.head(10).plot.bar() # Top 10
# Out:
# <Axes: >

# %% [markdown]
# ##Desafios del Aula 01

# %% [markdown]
# 1. Promedio de área de todos los barrios, y realizar un gráfico con el top 10
# 2. Consultar otros datos estadísticos: conteo, mediana, valores mínimos y máximos.

# %%
inmuebles.sample(10)
# Out:
#                      Tipo                                    Descripcion  \
# 2993          Apartamento                Apartamento en venta en Usaquén
# 8584          Apartamento                Apartamento en venta en Usaquén
# 1243          Apartamento     Apartamento en venta en Zona Noroccidental
# 5036          Apartamento        Apartamento en venta en Chico Reservado
# 4595  Oficina/Consultorio  Oficina/Consultorio en venta en Santa Barbara
# 1991          Apartamento                Apartamento en venta en Kennedy
# 7009          Apartamento                   Apartamento en venta en Bosa
# 3475          Apartamento                Apartamento en venta en Kennedy
# 3603          Apartamento            Apartamento en venta en Bella Suiza
# 8577          Apartamento     Apartamento en venta en Zona Noroccidental
#
#       Habitaciones  Banios  Area              Barrio  \
# 2993             3       2    61             Usaquén
# 8584             3       2    78             Usaquén
# 1243             3       2    60  Zona Noroccidental
# 5036             2       2   108     Chico Reservado
# 4595             4       4   240       Santa Barbara
# 1991             3       2    51             Kennedy
# 7009             3       1    47                Bosa
# 3475             3       1    51             Kennedy
# 3603             3       2   101         Bella Suiza
# 8577             3       4    98  Zona Noroccidental
#
#                                         UPZ            Valor
# 2993                                Usaquén    $ 270.000.000
# 8584                                Usaquén    $ 370.000.000
# 1243     CHAPINERO: Pardo Rubio + Chapinero    $ 209.500.000
# 5036     CHAPINERO: Chicó Lago + El Refugio    $ 780.000.000
# 4595  USAQUÉN: Country Club + Santa Bárbara  $ 1.250.000.000
# 1991                        Kennedy Central    $ 165.000.000
# 7009                           Bosa Central    $ 110.533.500
# 3475                        Kennedy Central    $ 172.000.000
# 3603  USAQUÉN: Country Club + Santa Bárbara    $ 499.500.000
# 8577     CHAPINERO: Pardo Rubio + Chapinero    $ 601.000.000

# %%
inmuebles[['Barrio', 'Area']]
# Out:
#                       Barrio  Area
# 0         Zona Noroccidental    70
# 1                   Castilla   170
# 2            Chico Reservado   144
# 3                    Usaquén   154
# 4                Bella Suiza   128
# ...                      ...   ...
# 9515                 Kennedy    70
# 9516  Parque Central Bavaria   100
# 9517                Restrepo   383
# 9518                Engativa   183
# 9519                 Tintala    52
#
# [9520 rows x 2 columns]

# %% [markdown]
# ### Método 1: Usando un ciclo for

# %%
import numpy as np

# Usando la libreria numpy, ordenamos alfabeticamente los diferentes barrios
# y los guardamos en una variable

barrios = np.sort(inmuebles.Barrio.unique())
barrios
# Out:
# array(['Alameda', 'Alhambra', 'Andes Norte', 'Antonio Nariño',
#        'Barrancas', 'Barrios Unidos', 'Bella Suiza',
#        'Bellavista Occidental', 'Bochica', 'Bogotá D.C', 'Bosa',
#        'Bosa Piamonte', 'Bosa Porvenir', 'Bosque De Pinos',
#        'Bosque Popular', 'Boyaca ', 'Buenos Aires', 'Candelaria La Nueva',
#        'Cantagallo', 'Capellania', 'Casablanca', 'Castilla', 'Cedritos',
#        'Cerros De Suba', 'Chapinero', 'Chapinero Alto',
#        'Chapinero Central', 'Chico Navarra', 'Chico Norte',
#        'Chico Norte Ii', 'Chico Reservado', 'Ciudad Berna',
#        'Ciudad Bolívar', 'Ciudad Salitre', 'Ciudadela Colsubsidio',
#        'Colina Campestre', 'Colinas De Suba', 'Costa Azul',
#        'Eduardo Santos', 'El Batán', 'El Castillo', 'El Chicó',
#        'El Contador', 'El Plan', 'El Progreso', 'El Refugio', 'El Retiro',
#        'El Salitre', 'El Tunal', 'El Virrey', 'Engativa', 'Estrada',
#        'Florencia', 'Florida Blanca', 'Fontibón', 'Galerias', 'Galicia',
#        'Gran America', 'Gran Granada', 'Gratamira', 'Gustavo Restrepo',
#        'Hayuelos', 'Ingles', 'Kennedy', 'La Calleja', 'La Candelaria',
#        'La Estancia', 'La Estanzuela', 'La Granja', 'La Macarena',
#        'La Merced', 'La Sabana', 'La Salle', 'La Soledad ', 'La Uribe',
#        'Lago De Suba', 'Lagos De Cordoba', 'Las Aguas', 'Las Cruces',
#        'Las Delicias', 'Las Ferias', 'Las Nieves', 'Las Villas',
#        'Libertador', 'Los Lagartos', 'Los Mártires', 'Los Rosales',
#        'Madelena', 'Marly', 'Mazuren', 'Metropolis', 'Mirandela ',
#        'Modelia', 'Nicolas De Federman', 'Niza', 'Normandia',
#        'Nueva Autopista', 'Nueva Castilla', 'Nueva Zelandia', 'Palermo',
#        'Parque Central Bavaria', 'Pasadena ', 'Patio Bonito',
#        'Pinar De Suba', 'Pontevedra ', 'Portales Del Norte',
#        'Prado Veraniego', 'Puente Aranda', 'Puente Largo',
#        'Quinta Camacho', 'Quinta Paredes', 'Quirigua', 'Quiroga',
#        'Rafael Uribe Uribe', 'Restrepo', 'Ricaurte', 'Roma', 'Salitre ',
#        'San Antonio Norte', 'San Cipriano', 'San Cristobal', 'San Diego',
#        'San Luis', 'San Patricio', 'Santa Ana', 'Santa Barbara',
#        'Santa Fe', 'Santa Librada', 'Santa Maria Del Lago', 'Santa Paula',
#        'Santa Teresa', 'Sotavento', 'Suba', 'Teusaquillo', 'Timiza',
#        'Tintala', 'Tunjuelito', 'Turingia', 'Usaquén', 'Usme', 'Venecia',
#        'Veraguas', 'Verbenal', 'Villa Alsacia', 'Villa Maria',
#        'Villas De Granada', 'Villemar', 'Zona Franca',
#        'Zona Noroccidental'], dtype=object)

# %%
# Creamos un dataframe vacio
area_estadistica = pd.DataFrame()

# Y recorremos cada barrio
for barrio in barrios:
  query = inmuebles.Barrio == barrio
  sub_dt = inmuebles[query]

  # Calculamos algunas cantidades estadísticas
  calculos = sub_dt[['Area']].describe().T
  calculos.index = [barrio]

  # Y concatenamos con el dataframe vacio anterior
  area_estadistica = pd.concat([area_estadistica, calculos], axis = 0)

area_estadistica.index.name = 'Barrio'
area_estadistica
# Out:
#                     count        mean         std   min     25%    50%  \
# Barrio
# Alameda               1.0   97.000000         NaN  97.0   97.00   97.0
# Alhambra             17.0  190.411765   99.782300  50.0  112.00  164.0
# Andes Norte           7.0  124.857143   49.780949  42.0  105.00  108.0
# Antonio Nariño       48.0  163.062500  151.023798  32.0   58.75   72.0
# Barrancas            15.0   70.200000    7.022413  63.0   63.00   75.0
# ...                   ...         ...         ...   ...     ...    ...
# Villa Maria          13.0  207.153846   47.310757  51.0  222.00  222.0
# Villas De Granada    22.0   86.590909   51.346312  50.0   64.00   64.0
# Villemar             18.0   76.888889   48.502139  45.0   54.25   59.0
# Zona Franca           1.0   54.000000         NaN  54.0   54.00   54.0
# Zona Noroccidental  877.0  135.785633  223.813808  16.0   61.00   78.0
#
#                        75%     max
# Barrio
# Alameda              97.00    97.0
# Alhambra            300.00   360.0
# Andes Norte         167.00   180.0
# Antonio Nariño      281.25   554.0
# Barrancas            76.50    78.0
# ...                    ...     ...
# Villa Maria         222.00   222.0
# Villas De Granada    80.50   260.0
# Villemar             59.00   224.0
# Zona Franca          54.00    54.0
# Zona Noroccidental  120.00  5458.0
#
# [149 rows x 8 columns]

# %% [markdown]
# ###Método 2: Usando groupby

# %%
area_estadistica = inmuebles[['Barrio','Area']].groupby('Barrio').describe()
area_estadistica.columns = [dato for _,dato in area_estadistica.columns]

area_estadistica
# Out:
#                     count        mean         std   min     25%    50%  \
# Barrio
# Alameda               1.0   97.000000         NaN  97.0   97.00   97.0
# Alhambra             17.0  190.411765   99.782300  50.0  112.00  164.0
# Andes Norte           7.0  124.857143   49.780949  42.0  105.00  108.0
# Antonio Nariño       48.0  163.062500  151.023798  32.0   58.75   72.0
# Barrancas            15.0   70.200000    7.022413  63.0   63.00   75.0
# ...                   ...         ...         ...   ...     ...    ...
# Villa Maria          13.0  207.153846   47.310757  51.0  222.00  222.0
# Villas De Granada    22.0   86.590909   51.346312  50.0   64.00   64.0
# Villemar             18.0   76.888889   48.502139  45.0   54.25   59.0
# Zona Franca           1.0   54.000000         NaN  54.0   54.00   54.0
# Zona Noroccidental  877.0  135.785633  223.813808  16.0   61.00   78.0
#
#                        75%     max
# Barrio
# Alameda              97.00    97.0
# Alhambra            300.00   360.0
# Andes Norte         167.00   180.0
# Antonio Nariño      281.25   554.0
# Barrancas            76.50    78.0
# ...                    ...     ...
# Villa Maria         222.00   222.0
# Villas De Granada    80.50   260.0
# Villemar             59.00   224.0
# Zona Franca          54.00    54.0
# Zona Noroccidental  120.00  5458.0
#
# [149 rows x 8 columns]

# %% [markdown]
# ###Creando gráficos

# %%
columnas = {
    'count' : 'contador',
    'mean' : 'promedio',
    'std' : 'd_estandar',
    '25%' : 'qt1',
    '50%' : 'mediana',
    '75%' : 'qt3'
}

area_estadistica = area_estadistica.rename(columns = columnas)

area_estadistica
# Out:
#                     contador    promedio  d_estandar   min     qt1  mediana  \
# Barrio
# Alameda                  1.0   97.000000         NaN  97.0   97.00     97.0
# Alhambra                17.0  190.411765   99.782300  50.0  112.00    164.0
# Andes Norte              7.0  124.857143   49.780949  42.0  105.00    108.0
# Antonio Nariño          48.0  163.062500  151.023798  32.0   58.75     72.0
# Barrancas               15.0   70.200000    7.022413  63.0   63.00     75.0
# ...                      ...         ...         ...   ...     ...      ...
# Villa Maria             13.0  207.153846   47.310757  51.0  222.00    222.0
# Villas De Granada       22.0   86.590909   51.346312  50.0   64.00     64.0
# Villemar                18.0   76.888889   48.502139  45.0   54.25     59.0
# Zona Franca              1.0   54.000000         NaN  54.0   54.00     54.0
# Zona Noroccidental     877.0  135.785633  223.813808  16.0   61.00     78.0
#
#                        qt3     max
# Barrio
# Alameda              97.00    97.0
# Alhambra            300.00   360.0
# Andes Norte         167.00   180.0
# Antonio Nariño      281.25   554.0
# Barrancas            76.50    78.0
# ...                    ...     ...
# Villa Maria         222.00   222.0
# Villas De Granada    80.50   260.0
# Villemar             59.00   224.0
# Zona Franca          54.00    54.0
# Zona Noroccidental  120.00  5458.0
#
# [149 rows x 8 columns]

# %%
area_promedio = area_estadistica['promedio'].sort_values(ascending = False)

area_promedio.head(10).plot(kind = 'bar', title = 'Top 10 Promedio de Áreas', ylabel = 'Área (m^2)')
# Out:
# <Axes: title={'center': 'Top 10 Promedio de Áreas'}, xlabel='Barrio', ylabel='Área (m^2)'>

# %%
area_d = area_estadistica['d_estandar'].sort_values(ascending = False)

area_d.head(10).plot(kind = 'bar', title = 'Top 10 desviación estándar del total de áreas', ylabel = 'Área (m^2)')
# Out:
# <Axes: title={'center': 'Top 10 desviación estándar del total de áreas'}, xlabel='Barrio', ylabel='Área (m^2)'>

# %%
area_contador = area_estadistica['contador'].sort_values(ascending = False)

area_contador.head(10).plot(kind = 'bar', title = 'Top 10 barrios con más inmuebles en venta', ylabel = 'count')
# Out:
# <Axes: title={'center': 'Top 10 barrios con más inmuebles en venta'}, xlabel='Barrio', ylabel='count'>

# %%
area_min = area_estadistica['min'].sort_values(ascending = False)

area_min.head(10).plot(kind = 'bar', title = 'Top 10 valores mínimos por barrio', ylabel = 'Área (m^2)')
# Out:
# <Axes: title={'center': 'Top 10 valores mínimos por barrio'}, xlabel='Barrio', ylabel='Área (m^2)'>

# %%
area_max = area_estadistica['max'].sort_values(ascending = False)

area_max.head(10).plot(kind = 'bar', title = 'Top 10 valores máximos por barrio', ylabel = 'Área (m^2)')
# Out:
# <Axes: title={'center': 'Top 10 valores máximos por barrio'}, xlabel='Barrio', ylabel='Área (m^2)'>

# %%
area_mediana = area_estadistica['mediana'].sort_values(ascending = False)

area_mediana.head(10).plot(kind = 'bar', title = 'Top 10 mediana de áreas por barrio', ylabel = 'Área (m^2)')
# Out:
# <Axes: title={'center': 'Top 10 mediana de áreas por barrio'}, xlabel='Barrio', ylabel='Área (m^2)'>

# %% [markdown]
# #Aula 02: Tratamiento de Datos y Primeras Gráficas

# %%
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 8135  Apartamento            Apartamento en venta en El Tunal             2
# 2660  Apartamento      Apartamento en venta en Chapinero Alto             3
# 3804  Apartamento        Apartamento en venta en San Patricio             3
# 3021         Casa                 Casa en venta en Tunjuelito             5
# 1728  Apartamento       Apartamento en venta en Villa Alsacia             3
# 6050  Apartamento  Apartamento en venta en Zona Noroccidental             2
# 4490  Apartamento      Apartamento en venta en Barrios Unidos             3
# 5281         Casa                       Casa en venta en Bosa             3
# 683   Apartamento    Apartamento en venta en Colina Campestre             3
# 1610  Apartamento            Apartamento en venta en El Batán             2
#
#       Banios  Area              Barrio                                    UPZ  \
# 8135       1    41            El Tunal                                Venecia
# 2660       3   100      Chapinero Alto     CHAPINERO: Pardo Rubio + Chapinero
# 3804       3   128        San Patricio  USAQUÉN: Country Club + Santa Bárbara
# 3021       3   210          Tunjuelito                             Tunjuelito
# 1728       2    86       Villa Alsacia            KENNEDY: Castilla + Bavaria
# 6050       1    44  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 4490       2    88      Barrios Unidos                              Los Andes
# 5281       1    47                Bosa                           Bosa Central
# 683        2    62    Colina Campestre                                   Niza
# 1610       2    91            El Batán                            La Alhambra
#
#               Valor
# 8135  $ 160.000.000
# 2660  $ 525.000.000
# 3804  $ 850.000.000
# 3021  $ 540.000.000
# 1728  $ 410.000.000
# 6050  $ 144.000.000
# 4490  $ 340.000.000
# 5281  $ 131.000.000
# 683   $ 281.000.000
# 1610  $ 445.000.000

# %% [markdown]
# ## Convertir columna str numerica a flotante

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banios        9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.Valor[0]
# Out:
# '$ 360.000.000'

# %%
type(inmuebles.Valor[0])
# Out:
# str

# %%
inmuebles.Valor[0] + inmuebles.Valor[1] # Concatenar str
# Out:
# '$ 360.000.000$ 670.000.000'

# %%
inmuebles.Valor[0].split()
# Out:
# ['$', '360.000.000']

# %%
valor_ = inmuebles.Valor.str.split(expand = True)
inmuebles['Moneda'] = valor_[0]
inmuebles['Precio'] = valor_[1]

inmuebles.sample(5)
# Out:
#              Tipo                        Descripcion  Habitaciones  Banios  \
# 7770         Casa          Casa en venta en Engativa             3       1
# 587          Casa      Casa en venta en Ciudad Berna             8       4
# 3474  Apartamento    Apartamento en venta en Kennedy             2       2
# 9312  Apartamento  Apartamento en venta en Chapinero             2       2
# 7943         Casa              Casa en venta en Bosa             5       3
#
#       Area        Barrio                                 UPZ            Valor  \
# 7770    90      Engativa                            Engativá    $ 320.000.000
# 587    400  Ciudad Berna                       Ciudad Jardín  $ 1.400.000.000
# 3474    54       Kennedy                     Kennedy Central    $ 250.000.000
# 9312    72     Chapinero  CHAPINERO: Pardo Rubio + Chapinero    $ 410.000.000
# 7943   240          Bosa                        Bosa Central    $ 375.000.000
#
#      Moneda         Precio
# 7770      $    320.000.000
# 587       $  1.400.000.000
# 3474      $    250.000.000
# 9312      $    410.000.000
# 7943      $    375.000.000

# %%
inmuebles['Precio'] = inmuebles['Precio'].str.replace('.', '', regex = True)

# %%
inmuebles[['Precio', 'Barrio']]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banios        9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
inmuebles['Precio_Millon'] = inmuebles['Precio'].astype('float')/1_000_000
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banios         9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 5769  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 8352  Apartamento          Apartamento en venta en La Calleja             3
# 8756  Apartamento             Apartamento en venta en Usaquén             3
# 3826  Apartamento  Apartamento en venta en Zona Noroccidental             2
# 7142  Apartamento                Apartamento en venta en Usme             2
# 6384  Apartamento             Apartamento en venta en Mazuren             3
# 5928  Apartamento            Apartamento en venta en El Batán             3
# 901   Apartamento             Apartamento en venta en Kennedy             2
# 2139  Apartamento     Apartamento en venta en Chico Reservado             3
# 5713  Apartamento      Apartamento en venta en Barrios Unidos             2
#
#       Banios  Area              Barrio                                    UPZ  \
# 5769       3    88  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 8352       2    90          La Calleja  USAQUÉN: Country Club + Santa Bárbara
# 8756       2    78             Usaquén                                Usaquén
# 3826       2    63  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 7142       1    38                Usme      USME: Alfonso López + Ciudad Usme
# 6384       2   120             Mazuren                               El Prado
# 5928       2    99            El Batán                            La Alhambra
# 901        2    55             Kennedy                        Kennedy Central
# 2139       4   164     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 5713       2    62      Barrios Unidos                              Los Andes
#
#                 Valor Moneda      Precio  Precio_Millon
# 5769    $ 650.000.000      $   650000000          650.0
# 8352    $ 468.000.000      $   468000000          468.0
# 8756    $ 370.000.000      $   370000000          370.0
# 3826    $ 345.000.000      $   345000000          345.0
# 7142     $ 82.000.000      $    82000000           82.0
# 6384    $ 390.000.000      $   390000000          390.0
# 5928    $ 860.000.000      $   860000000          860.0
# 901     $ 198.000.000      $   198000000          198.0
# 2139  $ 1.200.000.000      $  1200000000         1200.0
# 5713    $ 411.000.000      $   411000000          411.0

# %% [markdown]
# ## Función describe

# %%
inmuebles.describe()
# Out:
#        Habitaciones       Banios           Area  Precio_Millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %%
inmuebles.describe().round(2)
# Out:
#        Habitaciones   Banios       Area  Precio_Millon
# count       9520.00  9520.00    9520.00        9520.00
# mean           3.07     2.45     146.66         602.06
# std            2.05     1.26    1731.38         704.60
# min            1.00     0.00       2.00          60.00
# 25%            2.00     2.00      57.00         250.00
# 50%            3.00     2.00      80.00         409.18
# 75%            3.00     3.00     135.00         680.00
# max          110.00     9.00  166243.00       16000.00

# %% [markdown]
# Modificamos la visualización de los datos

# %%
pd.set_option('display.precision', 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

inmuebles.describe()
# Out:
#        Habitaciones  Banios      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %%
inmuebles.loc[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banios  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110       2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %%
inmuebles[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banios  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110       2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %%
inmuebles.loc[inmuebles.Area == 2]
# Out:
#              Tipo                            Descripcion  Habitaciones  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3
#
#       Banios  Area         Barrio      UPZ          Valor Moneda     Precio  \
# 8401       1     2  San Cristobal  Sosiego  $ 180.000.000      $  180000000
#
#       Precio_Millon
# 8401         180.00

# %% [markdown]
# ## Visualización de los datos

# %%
inmuebles['Precio_Millon'].plot.hist(bins = 100)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### Usando Matplotlib y Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize = (10,6))

grafica = sns.histplot(data = inmuebles, x = 'Precio_Millon', kde = True, hue = 'Tipo')
grafica.set_title('Distribución de Valores en los inmuebles en Bogotá')

plt.xlim((50,1000))
plt.savefig('/content/drive/MyDrive/Inmersion_datos_alura/img/valor_unmueble.png', format = 'png')
plt.show()

# %% [markdown]
# ## Desafio

# %% [markdown]
# 1. Estudiar mejor el histograma de valores, seleccionar 3 tipos de inmuebles (refinar el gráfico)
# 2. Precio del metro cuadrado por barrio, y encontrar un gráfico adecuado para esta nueva variable

# %% [markdown]
# ### Desafío 1

# %% [markdown]
# Vamos a trabajar con los 3 tipos de inmuebles que más se repitan en los datos

# %%
inmuebles.Tipo.value_counts()
# Out:
# Apartamento            7327
# Casa                   2043
# Oficina/Consultorio      60
# Local                    38
# Edificio                 22
# Bodega                   13
# Finca                    11
# Lote                      6
# Name: Tipo, dtype: int64

# %% [markdown]
# Los tipo de datos qué poseen una mayor frecuencia son

# %%
tipo_sel = ['Apartamento', 'Casa', 'Oficina/Consultorio']

# %% [markdown]
# Creamos el gráfico anterior únicamente usando estos tipos

# %%
plt.figure(figsize = (10,6))

inmuebles_simpl = inmuebles[inmuebles.Tipo.isin(tipo_sel)]

grafica = sns.histplot(data = inmuebles_simpl, x = 'Precio_Millon', kde = True, hue = 'Tipo')
grafica.set_title('Distribución de Valores en los inmuebles en Bogotá')

plt.xlim((50,2000))
#plt.savefig('/content/drive/MyDrive/Inmersion_datos_alura/img/valor_unmueble.png', format = 'png')
plt.show()

# %% [markdown]
# Ahora vamos a modificar las etiquetas y el titulo

# %%
plt.figure(figsize = (12,8))
sns.set_theme(font_scale = 1.5)

grafica = sns.histplot(data = inmuebles_simpl, x = 'Precio_Millon', kde = True, hue = 'Tipo')
grafica.set_title('Distribución de precios en los inmuebles en Bogotá')
grafica.set_xlabel('Precio (Millones COP)')
grafica.set_ylabel('Frecuencia')

plt.xlim((50,2000))
#plt.savefig('/content/drive/MyDrive/Inmersion_datos_alura/img/valor_unmueble.png', format = 'png')
plt.show()

# %% [markdown]
# Cambiamos la paleta de colores

# %%
plt.figure(figsize = (12,8))
sns.set_theme(font_scale = 1.5)

grafica = sns.histplot(data = inmuebles_simpl, x = 'Precio_Millon', kde = True, hue = 'Tipo', palette = 'dark',  multiple="stack")
grafica.set_title('Distribución de precios en los inmuebles en Bogotá')
grafica.set_xlabel('Precio (Millones COP)')
grafica.set_ylabel('Frecuencia')

plt.xlim((50,2000))
plt.savefig('/content/drive/MyDrive/Inmersion_datos_alura/img/valor_inmueble_top3.png', format = 'png')
plt.show()

# %% [markdown]
# Hacemos un zoom in para mirar el tipo Casa

# %%
plt.figure(figsize = (12,8))
sns.set_theme(font_scale = 1.5)

grafica = sns.histplot(data = inmuebles_simpl, x = 'Precio_Millon', kde = True, hue = 'Tipo', palette = 'dark',  multiple="stack")
grafica.set_title('Distribución de precios en los inmuebles en Bogotá')
grafica.set_xlabel('Precio (Millones COP)')
grafica.set_ylabel('Frecuencia')

plt.xlim((50,2000))
plt.ylim((0,110))
plt.savefig('/content/drive/MyDrive/Inmersion_datos_alura/img/valor_inmueble_top3_zoomin_1.png', format = 'png')
plt.show()

# %% [markdown]
# Ahora otro Zoom In para mirar el tipo Oficina y departamento

# %%
plt.figure(figsize = (12,8))
sns.set_theme(font_scale = 1.5)

grafica = sns.histplot(data = inmuebles_simpl, x = 'Precio_Millon', kde = True, hue = 'Tipo', palette = 'dark',  multiple="stack")
grafica.set_title('Distribución de precios en los inmuebles en Bogotá')
grafica.set_xlabel('Precio (Millones COP)')
grafica.set_ylabel('Frecuencia')

plt.xlim((50,2000))
plt.ylim((0,7))
plt.savefig('/content/drive/MyDrive/Inmersion_datos_alura/img/valor_inmueble_top3_zoomin_2.png', format = 'png')
plt.show()

# %% [markdown]
# ### Desafío 2

# %% [markdown]
# Visulizamos los datos

# %%
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 758   Apartamento           Apartamento en venta en Chapinero             1
# 1932  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 4987  Apartamento         Apartamento en venta en Chico Norte             1
# 3196  Apartamento       Apartamento en venta en Santa Barbara             2
# 1034  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 6458  Apartamento     Apartamento en venta en Chico Reservado             3
# 9477         Casa                       Casa en venta en Suba             3
# 5273  Apartamento                Apartamento en venta en Bosa             3
# 3830         Casa         Casa en venta en Zona Noroccidental             4
# 1041  Apartamento            Apartamento en venta en El Batán             2
#
#       Banios  Area              Barrio                                    UPZ  \
# 758        2    57           Chapinero     CHAPINERO: Pardo Rubio + Chapinero
# 1932       1    52  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 4987       1    76         Chico Norte     CHAPINERO: Chicó Lago + El Refugio
# 3196       2    81       Santa Barbara  USAQUÉN: Country Club + Santa Bárbara
# 1034       2    87  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 6458       4   152     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 9477       2    82                Suba                                   Suba
# 5273       1    47                Bosa                           Bosa Central
# 3830       3   280  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1041       2    55            El Batán                            La Alhambra
#
#                 Valor Moneda      Precio  Precio_Millon
# 758     $ 355.000.000      $   355000000         355.00
# 1932    $ 146.500.000      $   146500000         146.50
# 4987    $ 834.460.000      $   834460000         834.46
# 3196    $ 510.000.000      $   510000000         510.00
# 1034    $ 480.000.000      $   480000000         480.00
# 6458    $ 995.000.000      $   995000000         995.00
# 9477    $ 320.000.000      $   320000000         320.00
# 5273    $ 102.000.000      $   102000000         102.00
# 3830  $ 1.195.000.000      $  1195000000        1195.00
# 1041    $ 340.000.000      $   340000000         340.00

# %% [markdown]
# Creamos una columna nueva con el precio del metro cuadrado en cada caso.

# %%
inmuebles['Precio_por_m2'] = inmuebles.Precio_Millon / inmuebles.Area

inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 5009  Apartamento                Apartamento en venta en Suba             1
# 6111  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 5120  Apartamento         Apartamento en venta en Bella Suiza             3
# 462   Apartamento                Apartamento en venta en Bosa             2
# 9421         Casa                    Casa en venta en Kennedy             6
# 3308  Apartamento             Apartamento en venta en Usaquén             3
# 473   Apartamento        Apartamento en venta en San Patricio             2
# 5853  Apartamento      Apartamento en venta en Quinta Paredes             2
# 5509  Apartamento         Apartamento en venta en Teusaquillo             3
# 1948  Apartamento             Apartamento en venta en Usaquén             3
#
#       Banios  Area              Barrio                                    UPZ  \
# 5009       1    43                Suba                                   Suba
# 6111       2    74  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 5120       2   132         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
# 462        1    47                Bosa                           Bosa Central
# 9421       3   120             Kennedy                        Kennedy Central
# 3308       3    60             Usaquén                                Usaquén
# 473        2    72        San Patricio  USAQUÉN: Country Club + Santa Bárbara
# 5853       3   153      Quinta Paredes                            Teusaquillo
# 5509       2    58         Teusaquillo                            Teusaquillo
# 1948       2    72             Usaquén                                Usaquén
#
#               Valor Moneda     Precio  Precio_Millon  Precio_por_m2
# 5009  $ 270.000.000      $  270000000         270.00           6.28
# 6111  $ 255.000.000      $  255000000         255.00           3.45
# 5120  $ 900.000.000      $  900000000         900.00           6.82
# 462   $ 120.000.000      $  120000000         120.00           2.55
# 9421  $ 370.000.000      $  370000000         370.00           3.08
# 3308  $ 235.000.000      $  235000000         235.00           3.92
# 473   $ 420.000.000      $  420000000         420.00           5.83
# 5853  $ 739.000.000      $  739000000         739.00           4.83
# 5509  $ 116.000.000      $  116000000         116.00           2.00
# 1948  $ 379.000.000      $  379000000         379.00           5.26

# %% [markdown]
# Obtenemos algunos datos estadístico del precio por metro cuadrado

# %%
datos_est = inmuebles.groupby(by = 'Barrio').describe()

datos_est.sample(10)
# Out:
#                    Habitaciones                                           \
#                           count  mean  std   min   25%   50%   75%   max
# Barrio
# Pinar De Suba             11.00  2.82 0.40  2.00  3.00  3.00  3.00  3.00
# Puente Largo              30.00  2.80 0.76  1.00  2.25  3.00  3.00  4.00
# Estrada                    2.00 10.00 0.00 10.00 10.00 10.00 10.00 10.00
# Salitre                   11.00  3.27 0.79  2.00  3.00  3.00  3.50  5.00
# Normandia                 26.00  3.46 1.27  1.00  3.00  3.00  4.75  5.00
# Bosa                     589.00  2.96 1.07  2.00  3.00  3.00  3.00 12.00
# Gran Granada              54.00  3.02 0.69  1.00  3.00  3.00  3.00  4.00
# Galerias                   4.00  4.25 3.95  1.00  2.50  3.00  4.75 10.00
# Rafael Uribe Uribe        68.00  5.40 3.04  2.00  3.00  4.00  8.00 13.00
# Puente Aranda            116.00  4.55 2.88  1.00  3.00  3.00  6.00 16.00
#
#                    Banios       ... Precio_Millon         Precio_por_m2       \
#                     count mean  ...           75%     max         count mean
# Barrio                          ...
# Pinar De Suba       11.00 1.91  ...        318.75  385.00         11.00 3.90
# Puente Largo        30.00 2.77  ...        712.50 1350.00         30.00 4.84
# Estrada              2.00 5.00  ...        500.00  500.00          2.00 2.38
# Salitre             11.00 2.55  ...        807.70 1280.00         11.00 7.24
# Normandia           26.00 2.73  ...        935.00 1400.00         26.00 4.81
# Bosa               589.00 1.34  ...        147.30 2850.00        589.00 2.81
# Gran Granada        54.00 1.87  ...        331.25  410.00         54.00 3.93
# Galerias             4.00 2.75  ...        660.00 1350.00          4.00 5.51
# Rafael Uribe Uribe  68.00 3.00  ...        500.00 1500.00         68.00 3.29
# Puente Aranda      116.00 2.93  ...        722.50 2800.00        116.00 3.91
#
#
#                     std  min  25%  50%  75%   max
# Barrio
# Pinar De Suba      0.48 3.25 3.61 3.91 4.22  4.81
# Puente Largo       1.08 2.36 4.49 4.85 5.14  7.66
# Estrada            0.00 2.38 2.38 2.38 2.38  2.38
# Salitre            1.54 4.00 6.67 7.28 7.68  9.56
# Normandia          1.72 2.46 4.23 4.40 4.74  8.44
# Bosa               0.74 0.30 2.58 2.70 2.85  8.28
# Gran Granada       0.54 2.91 3.62 4.06 4.18  5.12
# Galerias           1.71 3.86 4.13 5.50 6.88  7.17
# Rafael Uribe Uribe 4.62 0.87 2.00 2.71 3.30 40.00
# Puente Aranda      1.89 1.54 2.57 3.49 4.56 12.28
#
# [10 rows x 40 columns]

# %%
datos_est.Precio_por_m2.sample(10)
# Out:
#                 count  mean  std  min  25%  50%  75%   max
# Barrio
# Eduardo Santos   2.00  4.31 3.34 1.95 3.13 4.31 5.49  6.67
# El Batán       133.00  5.38 1.09 2.92 4.72 5.38 6.15  8.69
# San Cipriano     3.00  5.13 0.80 4.67 4.67 4.67 5.36  6.06
# Pinar De Suba   11.00  3.90 0.48 3.25 3.61 3.91 4.22  4.81
# Chapinero Alto  35.00  7.11 1.90 4.14 6.01 7.05 8.08 12.72
# El Refugio      16.00  7.96 2.74 3.08 6.30 8.54 9.72 11.38
# Nueva Zelandia  15.00  4.76 1.26 2.24 4.15 5.13 5.33  7.10
# Galicia          5.00  2.81 1.10 1.67 1.77 2.78 3.92  3.92
# Engativa       462.00  3.89 1.28 0.03 3.21 3.82 4.52 12.50
# Mazuren         77.00  4.27 1.39 1.81 3.25 4.04 4.91  7.65

# %% [markdown]
# Tomaremos el top 10 de promedios, con su respectiva desviación estándar

# %%
top_promedio_porM2 = datos_est.Precio_por_m2[['mean', 'std']].sort_values(by = 'mean', ascending=False).head(10)
top_promedio_porM2 = top_promedio_porM2.reset_index()
top_promedio_porM2
# Out:
#             Barrio  mean  std
# 0        El Virrey 10.20 2.01
# 1        Santa Ana  9.36 2.12
# 2        La Merced  8.98 1.01
# 3      Chico Norte  8.54 2.70
# 4      Los Rosales  8.17 2.75
# 5       El Refugio  7.96 2.74
# 6       Las Nieves  7.89 2.66
# 7        El Retiro  7.72 2.27
# 8  Chico Reservado  7.61 2.89
# 9        Chapinero  7.43 2.55

# %% [markdown]
# Vamos a probar varias graficas para encontrar la mejor

# %% [markdown]
# LinePlot

# %%
sns.set_theme()
plt.figure(figsize = (10,8))

sns.lineplot(data = top_promedio_porM2, y = 'mean', x = 'Barrio', marker = 'o')

sigma = top_promedio_porM2['std']
x = top_promedio_porM2['Barrio']
y = top_promedio_porM2['mean']
plt.errorbar(x = x, y = y, yerr=(sigma, sigma), fmt='none', color='r', capsize=5)

plt.title('Promedio del costo por m2 por barrio')
plt.xlabel('Barrio')
plt.ylabel('Promedio')
plt.xticks(rotation = 80)
plt.show()

# %% [markdown]
# Barplot

# %%
sns.set_theme()
plt.figure(figsize = (10,8))

sns.barplot(data = top_promedio_porM2, y = 'mean', x = 'Barrio')

sigma = top_promedio_porM2['std']
x = top_promedio_porM2['Barrio']
y = top_promedio_porM2['mean']
plt.errorbar(x = x, y = y, yerr=(sigma, sigma), fmt='none', color='k', capsize=5)

plt.title('Top 10 Promedio del costo por m2 por barrio')
plt.xlabel('Barrio')
plt.ylabel('Promedio (millones COP)')
plt.xticks(rotation = 80)
plt.savefig('/content/drive/MyDrive/Inmersion_datos_alura/img/top10_primedio_costo_m2.png', format = 'png')
plt.show()
